# %%
import pandas as pd

# %%
df = pd.read_csv('ROIC2.csv', index_col = 0)

# %%
df['법인세비율'] = df['법인세비용']/(df['매출액'] - df['매출원가'] - df['판관비'])*100

# %%
df
# Out:
#             회사명   거래소코드     회계년도           매출액          판관비          매출원가  \
# 0      (주)MH에탄올   23150  2020/12  9.464524e+07   19039358.0  5.982396e+07
# 1      (주)MH에탄올   23150  2021/12  1.020669e+08   20520350.0  5.821127e+07
# 2      (주)MH에탄올   23150  2022/12  1.107224e+08   21335599.0  6.746191e+07
# 3      (주)MH에탄올   23150  2023/12  1.054841e+08   21987910.0  6.457866e+07
# 4     (주)SIMPAC    9160  2020/12  3.658633e+08   29890518.0  3.281854e+08
# ...         ...     ...      ...           ...          ...           ...
# 1857    효성화학(주)  298000  2023/12  2.791629e+09  111042585.0  2.869423e+09
# 1858    흥아해운(주)    3280  2020/12  8.893884e+07   13143526.0  8.159286e+07
# 1859    흥아해운(주)    3280  2021/12  8.172431e+07    7547899.0  7.605110e+07
# 1860    흥아해운(주)    3280  2022/12  1.778601e+08   15280780.0  1.329000e+08
# 1861    흥아해운(주)    3280  2023/12  1.648115e+08   18078419.0  1.221699e+08
#
#            법인세비용         ROIC       법인세비율
# ...

# %%
df.to_csv('ROIC2.csv')
