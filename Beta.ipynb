# %%
import datetime
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
warnings.filterwarnings('ignore')
market_symbol = "^KS11"

## 주간수익률
def week_price_ret(ticker_symbol,s_date,e_date):
    stock_symbol = ticker_symbol

    stock_data = yf.download(stock_symbol, start=s_date, end=e_date)
    stock_data = stock_data.set_index(pd.to_datetime(stock_data.index))

    weekly_returns = nstock_data['Adj Close'].resample('W-FRI').ffill().pct_change().dropna()

    return pd.DataFrame(weekly_returns)

# %%
np.log(stock_data['Adj Close'].resample('W-FRI').ffill()).pct_change().dropna()
# Out:
# Date
# 2020-01-10   -0.004244
# 2020-01-17   -0.001369
# 2020-01-24   -0.001950
# 2020-01-31   -0.009741
# 2020-02-07    0.007245
# 2020-02-14    0.003418
# 2020-02-21   -0.006333
# 2020-02-28   -0.006470
# 2020-03-06    0.000638
# 2020-03-13   -0.018739
# 2020-03-20   -0.016733
# 2020-03-27    0.011360
# 2020-04-03    0.005204
# 2020-04-10    0.008588
# 2020-04-17    0.003499
# 2020-04-24   -0.005635
# 2020-05-01    0.010059
# 2020-05-08    0.004175
# 2020-05-15   -0.007810
# 2020-05-22    0.009128
# 2020-05-29   -0.003142
# 2020-06-05    0.000000
# 2020-06-12   -0.003911
# 2020-06-19   -0.000334
# 2020-06-26   -0.003055
# 2020-07-03    0.005528
# 2020-07-10   -0.003057
# 2020-07-17    0.000689
# 2020-07-24    0.002376
# 2020-07-31   -0.001348
# 2020-08-07   -0.001024
# 2020-08-14   -0.000344
# 2020-08-21   -0.001039
# 2020-08-28   -0.000349
# 2020-09-04    0.001733
# 2020-09-11    0.000684
# 2020-09-18    0.001354
# 2020-09-25   -0.005164
# 2020-10-02    0.001409
# ...

# %%
year = [2020,2021,2022,2023]

# %%
e_date = datetime.datetime(2020,12,31)
s_date = datetime.datetime(2020,1,1)
  
ko =  week_price_ret(market_symbol,s_date,e_date)
df = pd.read_csv('거래소코드.csv', index_col = 0)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
week_df = pd.DataFrame()
for i in range(0,len(df),4):
    code = df['거래소코드'][i].astype('str')
    while len(code) < 6:
        code = "0" + code
    code = code + '.ks'
    ticker =  week_price_ret(code,s_date,e_date)
    ticker = ticker.rename(columns={'Adj Close': df['회사명'][i]})
    week_df = pd.concat([week_df,ticker], axis = 1)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
hi1 = list(week_df.columns.unique())
hi2 = list(df['회사명'].unique())
difference = [x for x in hi2 if x not in hi1]
print(len(difference))
print(difference)
# Out:
# 0
# []

# %%
beta = []
for i in range(len(week_df.columns)):
    beta.append(np.cov(week_df.iloc[:,i].values,ko['Adj Close'].values)[0,1]/np.var(ko['Adj Close'].values))
    
beta_df = pd.DataFrame(np.array(beta).reshape(1,-1), index = ['beta'] ,columns = week_df.columns)

# %%
beta_df
# Out:
#       (주)MH에탄올  (주)SIMPAC  (주)SNT에너지  (주)SNT홀딩스  (주)TCC스틸   (주)강원랜드     (주)경농  \
# beta  0.183114   1.107735   0.968061   0.691076  1.470431  1.273895  1.393292
#
#       (주)경동나비엔  (주)경동도시가스     (주)경방  ...  현대코퍼레이션홀딩스(주)   화성산업(주)   화천기공(주)  \
# beta  1.086748   1.013768  0.800311  ...       1.332588  1.164419  0.791783
#
#        환인제약(주)  효성아이티엑스(주)  효성중공업(주)  효성첨단소재(주)  효성티앤씨(주)   효성화학(주)   흥아해운(주)
# beta  0.814101    0.898495  1.713369   1.532711  1.332379  1.503164  1.107582
#
# [1 rows x 452 columns]

# %%
non_risk = pd.read_csv('무위험수익률.csv',index_col=0)

# %%
non_risk
# Out:
#       무위험수익률
# 20  2.306114
# 21  1.440167
# 22  2.956837
# 23  3.965036

# %%
# non_risk+(rm - non_risk)*beta
capm_list = []
for i in range(len(beta_df.columns)):
    capm_list.append(non_risk.iloc[0,0] + (ko.mean() - non_risk.iloc[0,0])*beta_df.iloc[0,i])

capm_df = pd.DataFrame(np.array(capm_list).reshape(1,-1), index = ['capm'] ,columns = week_df.columns)

capm_df
# Out:
#       (주)MH에탄올  (주)SIMPAC  (주)SNT에너지  (주)SNT홀딩스  (주)TCC스틸   (주)강원랜드     (주)경농  \
# capm  1.884977  -0.241526   0.079706   0.716732 -1.075679 -0.623673 -0.898268
#
#       (주)경동나비엔  (주)경동도시가스     (주)경방  ...  현대코퍼레이션홀딩스(주)   화성산업(주)  화천기공(주)  \
# capm  -0.19326  -0.025414  0.465507  ...      -0.758658 -0.371892  0.48512
#
#        환인제약(주)  효성아이티엑스(주)  효성중공업(주)  효성첨단소재(주)  효성티앤씨(주)   효성화학(주)   흥아해운(주)
# capm  0.433792    0.239698 -1.634403  -1.218914 -0.758177 -1.150959 -0.241176
#
# [1 rows x 452 columns]

# %%
df_2020 = pd.concat([beta_df,capm_df])

# %%
df_2020
# Out:
#       (주)MH에탄올  (주)SIMPAC  (주)SNT에너지  (주)SNT홀딩스  (주)TCC스틸   (주)강원랜드     (주)경농  \
# beta  0.183114   1.107735   0.968061   0.691076  1.470431  1.273895  1.393292
# capm  1.884977  -0.241526   0.079706   0.716732 -1.075679 -0.623673 -0.898268
#
#       (주)경동나비엔  (주)경동도시가스     (주)경방  ...  현대코퍼레이션홀딩스(주)   화성산업(주)   화천기공(주)  \
# beta  1.086748   1.013768  0.800311  ...       1.332588  1.164419  0.791783
# capm -0.193260  -0.025414  0.465507  ...      -0.758658 -0.371892  0.485120
#
#        환인제약(주)  효성아이티엑스(주)  효성중공업(주)  효성첨단소재(주)  효성티앤씨(주)   효성화학(주)   흥아해운(주)
# beta  0.814101    0.898495  1.713369   1.532711  1.332379  1.503164  1.107582
# capm  0.433792    0.239698 -1.634403  -1.218914 -0.758177 -1.150959 -0.241176
#
# [2 rows x 452 columns]

# %%
def beta(year):
    e_date = datetime.datetime(year,12,31)
    s_date = datetime.datetime(year,1,1)
  
    market_symbol = "^KS11"
    ko =  week_price_ret(market_symbol,s_date,e_date)

    week_df = pd.DataFrame()
    for i in range(0,len(df),4):
        code = df['거래소코드'][i].astype('str')
        while len(code) < 6:
            code = "0" + code
        code = code + '.ks'
        ticker =  week_price_ret(code,s_date,e_date)
        ticker = ticker.rename(columns={'Adj Close': df['회사명'][i]})
        week_df = pd.concat([week_df,ticker], axis = 1)

    beta = []
    for i in range(len(week_df.columns)):
        beta.append(np.cov(week_df.iloc[:,i].values,ko['Adj Close'].values)[0,1]/np.var(ko['Adj Close'].values))
        
    beta_df = pd.DataFrame(np.array(beta).reshape(1,-1), index = ['beta'] ,columns = week_df.columns)
    
    return  beta_df

# %%
beta_2021 = beta(2021)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
# non_risk+(rm - non_risk)*beta
capm_list = []
for i in range(len(beta_df.columns)):
    capm_list.append(non_risk.iloc[1,0] + (ko.mean() - non_risk.iloc[1,0])*beta_2021.iloc[0,i])

capm_df = pd.DataFrame(np.array(capm_list).reshape(1,-1), index = ['capm'] ,columns = week_df.columns)

# %%
df_2021 = pd.concat([beta_2021,capm_df])

# %%
beta_2022 = beta(2022)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
# non_risk+(rm - non_risk)*beta
capm_list = []
for i in range(len(beta_df.columns)):
    capm_list.append(non_risk.iloc[2,0] + (ko.mean() - non_risk.iloc[2,0])*beta_2022.iloc[0,i])

capm_df = pd.DataFrame(np.array(capm_list).reshape(1,-1), index = ['capm'] ,columns = week_df.columns)

# %%
df_2022 = pd.concat([beta_2022,capm_df])

# %%
beta_2023 = beta(2023)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
# non_risk+(rm - non_risk)*beta
capm_list = []
for i in range(len(beta_df.columns)):
    capm_list.append(non_risk.iloc[2,0] + (ko.mean() - non_risk.iloc[3,0])*beta_2023.iloc[0,i])

capm_df = pd.DataFrame(np.array(capm_list).reshape(1,-1), index = ['capm'] ,columns = week_df.columns)

# %%
df_2023 = pd.concat([beta_2023,capm_df])

# %%
df_2023
# Out:
#       (주)MH에탄올  (주)SIMPAC  (주)SNT에너지  (주)SNT홀딩스  (주)TCC스틸   (주)강원랜드     (주)경농  \
# beta  0.680879   0.937387   0.358926   0.336794  2.278625  0.945445  0.783235
# capm  0.261381  -0.754079   1.535926   1.623541 -6.063753 -0.785980 -0.143823
#
#       (주)경동나비엔  (주)경동도시가스     (주)경방  ...  현대코퍼레이션홀딩스(주)   화성산업(주)   화천기공(주)  \
# beta  0.206361   0.592852  0.293470  ...       0.468624  0.623541  0.655647
# capm  2.139896   0.609862  1.795054  ...       1.101653  0.488372  0.361272
#
#        환인제약(주)  효성아이티엑스(주)  효성중공업(주)  효성첨단소재(주)  효성티앤씨(주)   효성화학(주)   흥아해운(주)
# beta  0.403483    0.391800  0.656147   1.398793  0.863131  1.090790  0.329948
# capm  1.359535    1.405783  0.359291  -2.580686 -0.460113 -1.361369  1.650641
#
# [2 rows x 452 columns]

# %%
df_2022
# Out:
#       (주)MH에탄올  (주)SIMPAC  (주)SNT에너지  (주)SNT홀딩스  (주)TCC스틸   (주)강원랜드     (주)경농  \
# beta  1.204786   1.395159   1.384057   0.580419  1.478374  0.558739  1.016702
# capm -0.597989  -1.159700  -1.126944   1.244260 -1.405235  1.308227 -0.043030
#
#       (주)경동나비엔  (주)경동도시가스     (주)경방  ...  현대코퍼레이션홀딩스(주)   화성산업(주)   화천기공(주)  \
# beta  1.023386   0.720670  0.772754  ...       0.948337  0.974757  1.099529
# capm -0.062753   0.830438  0.676758  ...       0.158687  0.080730 -0.287421
#
#        환인제약(주)  효성아이티엑스(주)  효성중공업(주)  효성첨단소재(주)  효성티앤씨(주)   효성화학(주)   흥아해운(주)
# beta  0.474018    0.817672  1.163753   2.051252  1.408240  1.969905  1.451135
# capm  1.558204    0.544225 -0.476918  -3.095562 -1.198298 -2.855538 -1.324864
#
# [2 rows x 452 columns]

# %%
df_2021
# Out:
#       (주)MH에탄올  (주)SIMPAC  (주)SNT에너지  (주)SNT홀딩스  (주)TCC스틸   (주)강원랜드     (주)경농  \
# beta -0.033644   2.005239   1.120356   0.609775  0.770640  0.756774  0.923343
# capm  1.488411  -1.435181  -0.166331   0.565800  0.335133  0.355015  0.116169
#
#       (주)경동나비엔  (주)경동도시가스     (주)경방  ...  현대코퍼레이션홀딩스(주)   화성산업(주)   화천기공(주)  \
# beta  1.055457   0.944194  0.556052  ...       1.451429  1.233522  0.847793
# capm -0.073272   0.086270  0.642834  ...      -0.641063 -0.328602  0.224503
#
#        환인제약(주)  효성아이티엑스(주)  효성중공업(주)  효성첨단소재(주)  효성티앤씨(주)   효성화학(주)   흥아해운(주)
# beta  0.419324    1.634793  2.188166   1.535527  2.787218  2.862419  2.263472
# capm  0.838891   -0.903992 -1.697482  -0.761652 -2.556473 -2.664306 -1.805465
#
# [2 rows x 452 columns]

# %%
df_2020
# Out:
#       (주)MH에탄올  (주)SIMPAC  (주)SNT에너지  (주)SNT홀딩스  (주)TCC스틸   (주)강원랜드     (주)경농  \
# beta  0.183114   1.107735   0.968061   0.691076  1.470431  1.273895  1.393292
# capm  1.884977  -0.241526   0.079706   0.716732 -1.075679 -0.623673 -0.898268
#
#       (주)경동나비엔  (주)경동도시가스     (주)경방  ...  현대코퍼레이션홀딩스(주)   화성산업(주)   화천기공(주)  \
# beta  1.086748   1.013768  0.800311  ...       1.332588  1.164419  0.791783
# capm -0.193260  -0.025414  0.465507  ...      -0.758658 -0.371892  0.485120
#
#        환인제약(주)  효성아이티엑스(주)  효성중공업(주)  효성첨단소재(주)  효성티앤씨(주)   효성화학(주)   흥아해운(주)
# beta  0.814101    0.898495  1.713369   1.532711  1.332379  1.503164  1.107582
# capm  0.433792    0.239698 -1.634403  -1.218914 -0.758177 -1.150959 -0.241176
#
# [2 rows x 452 columns]

# %%
df['BETA'] = 0
df['CAPM'] = 0

# %%
df_list = [df_2020,df_2021,df_2022,df_2023]

# %%
# temp = 0
# for i in df_list:
#     for j in range(len(i.columns)):
#        df['BETA'][temp+j*4] = df_2020.iloc[0][j]
#     print(i)
for i in df_2020:
    print(i)
# Out:
# (주)MH에탄올
# (주)SIMPAC
# (주)SNT에너지
# (주)SNT홀딩스
# (주)TCC스틸
# (주)강원랜드
# (주)경농
# (주)경동나비엔
# (주)경동도시가스
# (주)경방
# (주)경인양행
# (주)광명전기
# (주)국동
# (주)금호에이치티
# (주)나이스홀딩스
# (주)남성
# (주)넥센
# (주)노루페인트
# (주)농심
# (주)다우기술
# (주)다이나믹디자인
# (주)대교
# (주)대우건설
# (주)대웅
# (주)대웅제약
# (주)대유에이텍
# (주)대창
# (주)대한항공
# (주)더블유게임즈
# (주)더존비즈온
# (주)덕성
# (주)덴티움
# (주)도화엔지니어링
# (주)동방
# (주)동방아그로
# (주)동서
# (주)동양
# (주)동양고속
# (주)동원에프앤비
# (주)드림텍
# (주)디비아이엔씨
# (주)디아이
# (주)디아이씨
# (주)디알비동일
# (주)디엔오토모티브
# (주)마니커
# (주)모나미
# (주)모토닉
# (주)무학
# (주)백산
# (주)보령
# (주)비와이씨
# (주)비지에프
# (주)비지에프리테일
# (주)빙그레
# (주)사조대림
# (주)삼양사
# (주)삼양홀딩스
# (주)삼익악기
# (주)삼천리
# (주)서연이화
# (주)서흥
# (주)선진
# (주)성안
# (주)세아베스틸지주
# (주)세아제강지주
# (주)세아특수강
# (주)세아홀딩스
# (주)세진중공업
# (주)셀트리온
# (주)솔루엠
# (주)수산인더스트리
# (주)수산중공업
# (주)시알홀딩스
# (주)신도리코
# (주)신성이엔지
# (주)신세계
# (주)신세계인터내셔날
# (주)신세계푸드
# (주)신영와코루
# (주)신풍
# (주)신흥
# (주)씨아이테크
# (주)씨티알모빌리티
# (주)아모레퍼시픽
# (주)아모레퍼시픽그룹
# (주)아이에이치큐
# (주)알루코
# (주)에스메디
# (주)에스비에스
# (주)에스원
# (주)에스지글로벌
# (주)에스지세계물산
# (주)에이치에스애드
# (주)에이프로젠
# (주)에이프로젠바이오로직스
# ...

# %%
for i in range(len(df_2020.columns)):
    df['BETA'][i*4] = df_2020.iloc[0,i]
    df['CAPM'][i*4] = df_2020.iloc[0,i]

# %%
for i in range(len(df_2021.columns)):
    df['BETA'][1+i*4] = df_2021.iloc[0,i]
    df['CAPM'][1+i*4] = df_2021.iloc[0,i]

# %%
for i in range(len(df_2022.columns)):
    df['BETA'][2+i*4] = df_2022.iloc[0,i]
    df['CAPM'][2+i*4] = df_2022.iloc[0,i]

# %%
for i in range(len(df_2023.columns)):
    df['BETA'][3+i*4] = df_2023.iloc[0,i]
    df['CAPM'][3+i*4] = df_2023.iloc[0,i]

# %%
df.to_csv('Beta_Capm.csv')
